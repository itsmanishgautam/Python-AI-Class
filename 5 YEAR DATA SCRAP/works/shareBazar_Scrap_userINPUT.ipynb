# %%
import requests
import re
from datetime import datetime

# Function to format date string
def format_date(date):
    return date.strftime("%Y-%m-%d")

# Define the URL and headers
url = "https://www.sharesansar.com/ajaxtodayshareprice"
headers = {
    "accept": "*/*",
    "accept-language": "en-GB,en-US;q=0.9,en;q=0.8",
    "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
    "cookie": "_gid=GA1.2.317488179.1716993804; _ga=GA1.2.1019898196.1716993802; _gat_gtag_UA_24700594_1=1; XSRF-TOKEN=%3D; sharesansar_session=%3D; _ga_FPXFBP3MT9=GS1.1.1717006970.4.1.1717007009.21.0.0",
    "dnt": "1",
    "origin": "https://www.sharesansar.com",
    "priority": "u=1, i",
    "referer": "https://www.sharesansar.com/today-share-price",
    "sec-ch-ua": "\"Google Chrome\";v=\"125\", \"Chromium\";v=\"125\", \"Not.A/Brand\";v=\"24\"",
    "sec-ch-ua-mobile": "?1",
    "sec-ch-ua-platform": "\"Android\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Mobile Safari/537.36",
    "x-requested-with": "XMLHttpRequest"
}

# Define the fixed date
user_input = input("Enter the date in AD in format: 2024-05-29: ")

fixed_date = datetime.strptime(user_input, "%Y-%m-%d")

# Prepare the data payload for the specific date
data = {
    "_token": "m6JbNo4WVFhonkMx18sOxqatLc01rS3rwgBideoK",
    "sector": "all_sec",
    "date": format_date(fixed_date)
}

# Make the POST request
response = requests.post(url, headers=headers, data=data)

# Check the response status
if response.status_code == 200:
    response_html = response.text
    print("Response for", data['date'], ":")
    # print(response_html)
else:
    print("Request failed for", format_date(fixed_date), "with status code:", response.status_code)
# Out:
# Response for 2024-05-26 :

# %%
# Extracting data within <thead> tags from both tables
thead_pattern = r'<thead>(.*?)</thead>'
thead_data = re.findall(thead_pattern, response_html, re.DOTALL)              

head_data_all = []

# Iterate over each element of thead_data and extract data within <th> tags
for data in thead_data:
    head_data = re.findall(r'<th.*?>(.*?)</th>', data, re.DOTALL)
    head_data_all.extend(head_data)

print("T_Head:", head_data_all)
# Out:
# T_Head: ['S.No', 'Symbol', 'Conf.', 'Open', 'High', 'Low', 'Close', 'VWAP', 'Vol', 'Prev. Close', 'Turnover', 'Trans.', 'Diff', 'Range', 'Diff %', 'Range %', 'VWAP %', '52 Weeks High', '52 Weeks Low']

# %%
# Extracting data within <tbody> tags
tbody_pattern = r'<tbody>(.*?)</tbody>'
tbody_data = re.findall(tbody_pattern, response_html, re.DOTALL)              

matches_data_all = []

# Iterate over each element of tbody_data and extract data within <td> tags
for data in tbody_data:
    matches_data = re.findall(r'<td.*?>(.*?)</td>', data, re.DOTALL)
    matches_data_all.extend(matches_data)

print("TBody:", matches_data_all)
# Out:
# TBody: ['1', '<a\n                        href="https://www.sharesansar.com/company/aclbsl"\n                        title="Aarambha Chautari Laghubitta Bittiya Sanstha Limited">ACLBSL</a>\n                ', '45.72', '914.00', '939.00', '914.00', '915.50', '927.94', '10,378.00', '930.00', '9,630,160.30', '131', '-14.50', '25.00', '-1.56', '2.74', '-1.36', '963.90', '500.10', '2', '<a\n                        href="https://www.sharesansar.com/company/adbl"\n                        title="Agricultural Development Bank Limited">ADBL</a>\n                ', '59.34', '285.00', '285.60', '276.00', '277.50', '280.25', '93,070.00', '280.00', '26,082,482.60', '546', '-2.50', '9.60', '-0.89', '3.48', '-0.99', '287.60', '223.00', '3', '<a\n                        href="https://www.sharesansar.com/company/adbld83"\n                        title="10.35% Agricultural Bank Debenture 2083">ADBLD83</a>\n                ', '47.56', '1,078.00', '1,078.00', '1,055.00', '1,055.00', '1,064.55', '550.00', '1,100.00', '585,500.80', '14', '-45.00', '23.00', '-4.09', '2.18', '-0.90', '1,144.00', '941.00', '4', '<a\n                        href="https://www.sharesansar.com/company/ahl"\n                        title="Asian Hydropower Limited">AHL</a>\n                ', '62.51', '486.00', '488.00', '455.00', '462.00', '462.81', '9,347.00', '479.00', '4,325,843.10', '114', '-17.00', '33.00', '-3.55', '7.25', '-0.17', '504.00', '273.10', '5', '<a\n                        href="https://www.sharesansar.com/company/ahpc"\n                        title="Arun Valley Hydropower Development Company Limited">AHPC</a>\n                ', '65.30', '166.00', '166.00', '161.10', '164.80', '162.87', '272,417.00', '163.80', '44,369,040.00', '796', '1.00', '4.90', '0.61', '3.04', '1.17', '316.00', '150.00', '6', '<a\n                        href="https://www.sharesansar.com/company/akjcl"\n                        title="Ankhukhola Hydropower Company Limited">AKJCL</a>\n                ', '53.94', '208.00', '210.00', '205.50', '206.00', '206.62', '17,867.00', '208.00', '3,691,602.40', '86', '-2.00', '4.50', '-0.96', '2.19', '-0.30', '250.00', '141.30', '7', '<a\n                        href="https://www.sharesansar.com/company/akpl"\n                        title="Arun Kabeli Power Limited">AKPL</a>\n                ', '58.49', '170.00', '173.60', '169.00', '172.40', '171.00', '89,043.00', '170.20', '15,226,778.00', '335', '2.20', '4.60', '1.29', '2.72', '0.81', '384.90', '152.40', '8', '<a\n                        href="https://www.sharesansar.com/company/albsl"\n                        title="Asha Laghubitta Bittiya Sanstha Limited">ALBSL</a>\n                ', '55.38', '957.00', '970.90', '939.00', '950.00', '955.63', '50,320.00', '957.60', '48,087,307.40', '339', '-7.60', '31.90', '-0.79', '3.40', '-0.59', '989.90', '543.00', '9', '<a\n                        href="https://www.sharesansar.com/company/alicl"\n                        title="Asian Life Insurance Company Limited">ALICL</a>\n                ', '45.65', '585.00', '589.90', '578.30', '584.40', '582.19', '30,988.00', '590.00', '18,040,811.30', '239', '-5.60', '11.60', '-0.95', '2.01', '0.38', '812.00', '523.00', '10', '<a\n                        href="https://www.sharesansar.com/company/anlb"\n                        title="Aatmanirbhar Laghubitta Bittiya Sanstha Limited">ANLB</a>\n                ', '50.97', '2,255.00', '2,385.00', '2,223.00', '2,383.80', '2,338.01', '5,211.00', '2,255.00', '12,183,383.10', '106', '128.80', '162.00', '5.71', '7.29', '1.92', '2,651.00', '1,533.00', '11', '<a\n                        href="https://www.sharesansar.com/company/api"\n                        title="Api Power Company Limited">API</a>\n                ', '50.70', '180.50', '180.50', '173.60', '174.00', '175.06', '92,141.00', '177.00', '16,130,257.30', '404', '-3.00', '6.90', '-1.69', '3.97', '-0.61', '265.20', '154.70', '12', '<a\n                        href="https://www.sharesansar.com/company/avyan"\n         ...

# %%
num_columns = len(head_data_all)
print(len(head_data_all))

# Split the data into sublists for each row
sublists = [matches_data_all[i:i+num_columns] for i in range(0, len(matches_data_all), num_columns)]
print(sublists)
# Out:
# 19
# [['1', '<a\n                        href="https://www.sharesansar.com/company/aclbsl"\n                        title="Aarambha Chautari Laghubitta Bittiya Sanstha Limited">ACLBSL</a>\n                ', '45.72', '914.00', '939.00', '914.00', '915.50', '927.94', '10,378.00', '930.00', '9,630,160.30', '131', '-14.50', '25.00', '-1.56', '2.74', '-1.36', '963.90', '500.10'], ['2', '<a\n                        href="https://www.sharesansar.com/company/adbl"\n                        title="Agricultural Development Bank Limited">ADBL</a>\n                ', '59.34', '285.00', '285.60', '276.00', '277.50', '280.25', '93,070.00', '280.00', '26,082,482.60', '546', '-2.50', '9.60', '-0.89', '3.48', '-0.99', '287.60', '223.00'], ['3', '<a\n                        href="https://www.sharesansar.com/company/adbld83"\n                        title="10.35% Agricultural Bank Debenture 2083">ADBLD83</a>\n                ', '47.56', '1,078.00', '1,078.00', '1,055.00', '1,055.00', '1,064.55', '550.00', '1,100.00', '585,500.80', '14', '-45.00', '23.00', '-4.09', '2.18', '-0.90', '1,144.00', '941.00'], ['4', '<a\n                        href="https://www.sharesansar.com/company/ahl"\n                        title="Asian Hydropower Limited">AHL</a>\n                ', '62.51', '486.00', '488.00', '455.00', '462.00', '462.81', '9,347.00', '479.00', '4,325,843.10', '114', '-17.00', '33.00', '-3.55', '7.25', '-0.17', '504.00', '273.10'], ['5', '<a\n                        href="https://www.sharesansar.com/company/ahpc"\n                        title="Arun Valley Hydropower Development Company Limited">AHPC</a>\n                ', '65.30', '166.00', '166.00', '161.10', '164.80', '162.87', '272,417.00', '163.80', '44,369,040.00', '796', '1.00', '4.90', '0.61', '3.04', '1.17', '316.00', '150.00'], ['6', '<a\n                        href="https://www.sharesansar.com/company/akjcl"\n                        title="Ankhukhola Hydropower Company Limited">AKJCL</a>\n                ', '53.94', '208.00', '210.00', '205.50', '206.00', '206.62', '17,867.00', '208.00', '3,691,602.40', '86', '-2.00', '4.50', '-0.96', '2.19', '-0.30', '250.00', '141.30'], ['7', '<a\n                        href="https://www.sharesansar.com/company/akpl"\n                        title="Arun Kabeli Power Limited">AKPL</a>\n                ', '58.49', '170.00', '173.60', '169.00', '172.40', '171.00', '89,043.00', '170.20', '15,226,778.00', '335', '2.20', '4.60', '1.29', '2.72', '0.81', '384.90', '152.40'], ['8', '<a\n                        href="https://www.sharesansar.com/company/albsl"\n                        title="Asha Laghubitta Bittiya Sanstha Limited">ALBSL</a>\n                ', '55.38', '957.00', '970.90', '939.00', '950.00', '955.63', '50,320.00', '957.60', '48,087,307.40', '339', '-7.60', '31.90', '-0.79', '3.40', '-0.59', '989.90', '543.00'], ['9', '<a\n                        href="https://www.sharesansar.com/company/alicl"\n                        title="Asian Life Insurance Company Limited">ALICL</a>\n                ', '45.65', '585.00', '589.90', '578.30', '584.40', '582.19', '30,988.00', '590.00', '18,040,811.30', '239', '-5.60', '11.60', '-0.95', '2.01', '0.38', '812.00', '523.00'], ['10', '<a\n                        href="https://www.sharesansar.com/company/anlb"\n                        title="Aatmanirbhar Laghubitta Bittiya Sanstha Limited">ANLB</a>\n                ', '50.97', '2,255.00', '2,385.00', '2,223.00', '2,383.80', '2,338.01', '5,211.00', '2,255.00', '12,183,383.10', '106', '128.80', '162.00', '5.71', '7.29', '1.92', '2,651.00', '1,533.00'], ['11', '<a\n                        href="https://www.sharesansar.com/company/api"\n                        title="Api Power Company Limited">API</a>\n                ', '50.70', '180.50', '180.50', '173.60', '174.00', '175.06', '92,141.00', '177.00', '16,130,257.30', '404', '-3.00', '6.90', '-1.69', '3.97', '-0.61', '265.20', '154.70'], ['12', '<a\n                        href="https://www.sharesansar.com/company/ ...

# %%
# List to store company names
company_names = []

# Regular expression pattern to match the title attribute
company_pattern = r'title="([^"]+)"'

# Loop through each sublist and extract company names
for sublist in sublists:
    for item in sublist:
        match = re.search(company_pattern, item)
        if match:
            company_names.append(match.group(1))

print(company_names)
# Out:
# ['Aarambha Chautari Laghubitta Bittiya Sanstha Limited', 'Agricultural Development Bank Limited', '10.35% Agricultural Bank Debenture 2083', 'Asian Hydropower Limited', 'Arun Valley Hydropower Development Company Limited', 'Ankhukhola Hydropower Company Limited', 'Arun Kabeli Power Limited', 'Asha Laghubitta Bittiya Sanstha Limited', 'Asian Life Insurance Company Limited', 'Aatmanirbhar Laghubitta Bittiya Sanstha Limited', 'Api Power Company Limited', 'Aviyan Laghubitta Bittiya Sanstha Limited', 'Barun Hydropower Company Limited', 'Bishal Bazar Company Limited', 'Bhugol Energy Development Company Limited', 'Best Finance Company Limited', 'Bhagawati Hydropower Development Company Limited', 'Bindhyabasini Hydropower Development Company Limited', 'Balephi Hydropower Limited', 'Barahi Hydropower Public Limited', 'Buddha Bhumi Nepal Hydropower Company Limited', 'Bottlers Nepal Limited (Balaju)', 'Bottlers Nepal (Terai) Limited', '8.5% BOK Debenture 2086', 'Butwal Power Company Limited', 'Citizens Super 30 Mutual Fund', 'Chhimek Laghubitta Bittiya Sanstha Limited', '10.25% Civil Bank Debenture 2088', '10.50% Century Debenture 2088', 'Central Finance Limited', 'Chandragiri Hills Limited', 'Chilime Hydro power Company Limited', 'CEDB Hydropower Development Company Limited', 'Chhyangdi Hydropower Company Limited', 'Citizen Investment Trust', 'City Hotel Limited', '10.25% Citizens Bank Debenture 2086', 'Chirkhwa Hydro Power Limited', 'Citizen Life Insurance Company Limited', 'Citizens Mutual Fund-1', 'Citizens Mutual Fund - 2', 'Corporate Development Bank Limited', 'CYC Nepal Laghubitta Bittiya Sanstha Limited', 'Citizens Bank International Limited', 'Deprosc Laghubitta Bittiya Sanstha Limited', 'Dibyashwari Hydropower Company Limited', 'Dhaulagiri Laghubitta Bittiya Sanstha Limited', 'Dolti Power Company Ltd', 'Dordi Khola Hydropower Company Limited', 'Everest Bank Limited', 'Excel Development Bank Limited', 'Eastern Hydropower Limited', 'Emerging Nepal Limited', 'First Microfinance Laghubitta Bittiya Sanstha Limited', 'Forward Microfinance Laghubitta Bittiya Sanstha Limited', '8.75% Garima Debenture 2085', 'Garima Bikas Bank Limited', 'Global IME Bank Limited', 'Grameen Bikas Laghubitta Bittiya Sanstha Limited', 'Ghorahi Cement Industry Limited', 'Goodwill Finance Company Limited', 'Ghalemdi Hydro Limited', 'Global IME Balance Fund-I', 'Global IME Laghubitta Bittiya Sanstha Limited', 'Gurans Laghubitta Bittiya Sanstha Limited', 'Greenlife Hydropower Limited', 'Ganapati Laghubitta Bittiya Sanstha Limited', 'Guheswori Merchant Banking &amp; Finance Limited', 'Green Development Bank Limited', 'Gurkhas Finance Limited', 'Green Ventures Limited', '12% Goodwill Finance Limited Debenture 2083', 'Himalayan 80-20', 'Hathway Investment Nepal Limited', 'Himalayan Bank Limited', 'Himal Dolakha Hydropower Company Limited', 'Himalayan Distillery Limited', 'Himalayan Everest Insurance Limited', 'Himalayan Everest Insurance Limited Promoter', 'Himalayan Hydropower Limited', 'Hydroelectricity Investment and Development Company Limited', 'Hydroelectricity Investment and Development Company Limited Promoter Share', 'Himalayan Laghubitta Bittiya Sanstha Limited (Former Civil Laghubitta)', 'Himalayan Life Insurance Limited', 'Himalayan Power Partner Limited', 'Himalayan Reinsurance Limited', 'Himalaya Urja Bikas Company Limited', 'ICFC Finance Limited', '12% ICFC Finance Limited Debenture 2083', 'IGI Prudential Insurance Limited', 'Ingwa Hydropower Ltd', 'Infinity Laghubitta Bittiya Sanstha Limited', 'IME Life Insurance Company Limited', 'Jalpa  Samudayik Laghubitta Bittiya Sanstha Limited', 'Jyoti Bikash Bank Limited', 'Jeevan Bikas Laghubitta Bittiya Sanstha Limited', 'Janaki Finance Company Limited', 'Joshi Hydropower Development Company Limited', 'Janautthan Samudayic Laghubitta Bittiya Sanstha Limited', 'Kumari Bank Limited', '10.25% Kumari Bank Debenture 2086', '11% KBL Debenture 2089', 'Kutheli Bukhari Small Hydropower Limited', 'Kumari Dhanabriddh ...

# %%
import re
import csv
from datetime import datetime



# List to store company names
company_names = []

# Regular expression pattern to match the title attribute
company_pattern = r'title="([^"]+)"'

# Loop through each sublist and extract company names
for sublist in sublists:
    for item in sublist:
        match = re.search(company_pattern, item)
        if match:
            company_names.append(match.group(1))

# Function to extract symbol from HTML anchor tag
def extract_symbol(html):
    name_match = re.search(r'>([^<]+)<', html)
    symbol = name_match.group(1) if name_match else None
    return symbol


# Convert sublists to list of dictionaries
data = []

if sublists == [[' No Record Found.']]:
    print("No Record Found")
else:
    for i, sublist in enumerate(sublists):
        symbol = extract_symbol(sublist[1])
        entry = {head_data_all[0]: sublist[0], head_data_all[1]: symbol}
        entry.update(dict(zip(head_data_all[2:], sublist[2:])))
        entry['Company Name'] = company_names[i]
        data.append(entry)


    file_name = f"data_{format_date(fixed_date)}.csv"

    # Write data to CSV
    with open(file_name, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=head_data_all + ['Company Name'])
        # Write header
        writer.writeheader()
        # Write rows
        for row in data:
            writer.writerow(row)

    print(f"Data has been written to {file_name}")
# Out:
# Data has been written to data_2024-05-26.csv

# %%
# # Define the file name
# import csv
# file_name = f"data_{format_date(fixed_date)}.csv"

# # Write data to CSV
# with open(file_name, mode='w', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=head_data_all + ['URL', 'Company Name', 'Title'])
#     # Write header
#     writer.writeheader()
#     # Write rows
#     for row in data:
#         writer.writerow(row)

# print(f"Data has been written to {file_name}")
