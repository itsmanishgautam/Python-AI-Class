# %%
import re
import csv

html_content = '''
<h5>As of : <span class="text-org">2024-05-26</span></h5>
<div class="headFixedWrapper">
    <table id="headFixed" class="table table-bordered table-striped table-hover dataTable compact">
        <thead>
            <tr>
                <th width="10px">S.No</th>
                <th>Symbol</th>
                <th class="text-center" title="Stock Confidence">Conf.</th>
                <th class="text-center">Open</th>
                <th class="text-center">High</th>
                <th class="text-center">Low</th>
                <th class="text-center">Close</th>
                <th class="text-center">VWAP</th>
                <th class="text-center">Vol</th>
                <th class="text-center">Prev. Close</th>
                <th class="text-center">Turnover</th>
                <th class="text-center">Trans.</th>
                <th class="text-center">Diff</th>
                <th class="text-center">Range</th>
                <th class="text-center">Diff %</th>
                <th class="text-center">Range %</th>
                <th class="text-center">VWAP %</th>
                <th class="text-center">52 Weeks High</th>
                <th class="text-center">52 Weeks Low</th>
            </tr>
        </thead>
        <tbody>
            <tr>
                <td class="danger-index">1</td>
                <td class="danger-index"><a href="https://www.sharesansar.com/company/aclbsl" title="Aarambha Chautari Laghubitta Bittiya Sanstha Limited">ACLBSL</a></td>
                <td class="text-center bg-success">45.72</td>
                <td class="text-center">914.00</td>
                <td class="text-center">939.00</td>
                <td class="text-center">914.00</td>
                <td class="danger-index text-center">915.50</td>
                <td class="light-blue text-center">927.94</td>
                <td class="text-center">10,378.00</td>
                <td class="text-center">930.00</td>
                <td class="text-center">9,630,160.30</td>
                <td class="text-center">131</td>
                <td class="danger-index text-center">-14.50</td>
                <td class="danger-index text-center">25.00</td>
                <td class="light-blue text-center">-1.56</td>
                <td class="light-blue text-center">2.74</td>
                <td class="light-blue text-center">-1.36</td>
                <td class="text-center bg-success">963.90</td>
                <td class="text-center bg-success">500.10</td>
            </tr>
            <tr>
                <td class="danger-index">2</td>
                <td class="danger-index"><a href="https://www.sharesansar.com/company/adbl" title="Agricultural Development Bank Limited">ADBL</a></td>
                <td class="text-center bg-success">59.34</td>
                <td class="text-center">285.00</td>
                <td class="text-center">285.60</td>
                <td class="text-center">276.00</td>
                <td class="danger-index text-center">277.50</td>
                <td class="light-blue text-center">280.25</td>
                <td class="text-center">93,070.00</td>
                <td class="text-center">280.00</td>
                <td class="text-center">26,082,482.60</td>
                <td class="text-center">546</td>
                <td class="danger-index text-center">-2.50</td>
                <td class="danger-index text-center">9.60</td>
                <td class="light-blue text-center">-0.89</td>
                <td class="light-blue text-center">3.48</td>
                <td class="light-blue text-center">-0.99</td>
                <td class="text-center bg-success">287.60</td>
                <td class="text-center bg-success">223.00</td>
            </tr>
        </tbody>
    </table>
</div>

<h5>As of : <span class="text-org">2024-05-27</span></h5>
<div class="headFixedWrapper">
    <table id="headFixed" class="table table-bordered table-striped table-hover dataTable compact">
        <thead>
            <tr>
                <th width="10px">S.No</th>
                <th>Symbol</th>
                <th class="text-center" title="Stock Confidence">Conf.</th>
                <th class="text-center">Open</th>
                <th class="text-center">High</th>
                <th class="text-center">Low</th>
                <th class="text-center">Close</th>
                <th class="text-center">VWAP</th>
                <th class="text-center">Vol</th>
                <th class="text-center">Prev. Close</th>
                <th class="text-center">Turnover</th>
                <th class="text-center">Trans.</th>
                <th class="text-center">Diff</th>
                <th class="text-center">Range</th>
                <th class="text-center">Diff %</th>
                <th class="text-center">Range %</th>
                <th class="text-center">VWAP %</th>
                <th class="text-center">52 Weeks High</th>
                <th class="text-center">52 Weeks Low</th>
            </tr>
        </thead>
        <tbody>
            <tr>
                <td class="success-index">1</td>
                <td class="success-index"><a href="https://www.sharesansar.com/company/aclbsl" title="Aarambha Chautari Laghubitta Bittiya Sanstha Limited">ACLBSL</a></td>
                <td class="text-center bg-success">48.77</td>
                <td class="text-center">897.20</td>
                <td class="text-center">951.00</td>
                <td class="text-center">880.00</td>
                <td class="success-index text-center">936.00</td>
                <td class="light-blue text-center">939.55</td>
                <td class="text-center">8,904.00</td>
                <td class="text-center">915.50</td>
                <td class="text-center">8,365,782.50</td>
                <td class="text-center">114</td>
                <td class="success-index text-center">20.50</td>
                <td class="success-index text-center">71.00</td>
                <td class="light-blue text-center">2.24</td>
                <td class="light-blue text-center">8.07</td>
                <td class="light-blue text-center">-0.38</td>
                <td class="text-center bg-success">963.90</td>
                <td class="text-center bg-success">500.10</td>
            </tr>
            <tr>
                <td class="danger-index">2</td>
                <td class="danger-index"><a href="https://www.sharesansar.com/company/adbl" title="Agricultural Development Bank Limited">ADBL</a></td>
                <td class="text-center bg-success">55.12</td>
                <td class="text-center">277.50</td>
                <td class="text-center">280.00</td>
                <td class="text-center">272.00</td>
                <td class="danger-index text-center">277.00</td>
                <td class="light-blue text-center">274.30</td>
                <td class="text-center">63,787.00</td>
                <td class="text-center">277.50</td>
                <td class="text-center">17,497,028.40</td>
                <td class="text-center">295</td>
                <td class="danger-index text-center">-0.50</td>
                <td class="danger-index text-center">8.00</td>
                <td class="light-blue text-center">-0.18</td>
                <td class="light-blue text-center">2.94</td>
                <td class="light-blue text-center">0.97</td>
                <td class="text-center bg-success">287.60</td>
                <td class="text-center bg-success">223.00</td>
            </tr>
        </tbody>
    </table>
</div>
'''

# Extract <thead>
thead_pattern = r'<thead>(.*?)</thead>'
thead_matches = re.findall(thead_pattern, html_content, re.DOTALL)

# Extract <tbody>
tbody_pattern = r'<tbody>(.*?)</tbody>'
tbody_matches = re.findall(tbody_pattern, html_content, re.DOTALL)

# Extract dates
date_pattern = r'<h5>As of : <span class="text-org">([\d-]+)</span></h5>'
date_matches = re.findall(date_pattern, html_content)

# Extract data rows
row_pattern = r'<tr>(.*?)</tr>'
rows = []
for tbody in tbody_matches:
    row_matches = re.findall(row_pattern, tbody, re.DOTALL)
    for row in row_matches:
        cell_pattern = r'<t[dh].*?>(.*?)</t[dh]>'
        cells = re.findall(cell_pattern, row, re.DOTALL)
        # Clean up cell values
        cells = [re.sub(r'<.*?>', '', cell).strip() for cell in cells]
        rows.append(cells)

# Merge dates with the extracted rows
data = []
date_index = 0
for i, row in enumerate(rows):
    if i > 0 and i % 2 == 0:
        date_index += 1
    date = date_matches[date_index]
    data.append([date] + row)

# Define the headers
headers = [
    "Date", "Name", "Symbol", "Conf", "Open", "High", "Low", "Close", "VWAP", "Vol", "Prev. Close", "Turnover",
    "Trans", "Diff", "Range", "Diff %", "Range %", "VWAP %", "120 Days", "180 Days", "52 Weeks High", "52 Weeks Low"
]

# Sample additional columns (120 Days and 180 Days) with random or calculated data
additional_columns = [
    [634.84, 615.22, 919.90, 500.10],  # Sample data for ACLBSL
    [238.76, 244.86, 275.00, 223.00]   # Sample data for ADBL
]

# Add additional columns to data
for i in range(len(data)):
    data[i].extend(additional_columns[i % len(additional_columns)])

# Write to CSV
csv_filename = "test_stock_data.csv"
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(headers)
    writer.writerows(data)

print(f"Data has been written to {csv_filename}")
# Out:
# Data has been written to test_stock_data.csv
