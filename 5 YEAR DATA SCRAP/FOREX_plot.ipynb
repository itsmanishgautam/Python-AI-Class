# %%
import matplotlib.pyplot as plt

# Data
currency = ['INR', 'USD', 'EUR', 'GBP', 'CHF', 'AUD', 'CAD', 'SGD', 'JPY', 'CNY', 'SAR', 'QAR', 'THB', 'AED', 'MYR', 'KRW', 'SEK', 'DKK', 'HKD', 'KWD', 'BHD']
buy = [160.00, 113.92, 127.83, 150.35, 117.84, 79.87, 87.45, 84.66, 10.50, 16.37, 30.37, 31.29, 3.82, 31.01, 27.85, 9.86, 12.25, 17.11, 14.63, 375.96, 302.12]
sell = [160.15, 114.52, 128.50, 151.14, 118.46, 80.29, 87.91, 85.11, 10.55, 16.45, 30.53, 31.45, 3.84, 31.18, 28.00, 9.92, 12.31, 17.20, 14.71, 377.94, 303.72]

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(currency, buy, color='skyblue', label='Buy')
plt.bar(currency, sell, color='orange', label='Sell', alpha=0.7)
plt.xlabel('Currency')
plt.ylabel('Exchange Rate')
plt.title('Currency Exchange Rates (Buy and Sell)')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.tight_layout()
plt.show()
