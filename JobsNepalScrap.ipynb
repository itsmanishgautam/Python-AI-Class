# %%
import urllib.request
url = 'http://www.jobsnepal.com'

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'

# %%
request = urllib.request.Request(url, headers={'User-Agent': user_agent})

# %%
response = urllib.request.urlopen(request)

# %%
print(response.read().decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="utf-8" />
#     <title>
#         Search Job - Find Jobs, Vacancy in Nepal | JobsNepal    </title>
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" />
# <meta name="csrf-token" content="xDXC7jknnpFXTxbdY9Rhy1DesSAcx2MMiUjx28Pu">
# <link href="https://www.jobsnepal.com/global/lib/icomoon/styles.css" type="text/css" rel="stylesheet">
# <link rel="preload" as="style" href="https://www.jobsnepal.com/build/assets/style-DWRjEJYb.css" /><link rel="preload" as="style" href="https://www.jobsnepal.com/build/assets/style-9WxHJm-q.css" /><link rel="preload" as="style" href="https://www.jobsnepal.com/build/assets/tailwind-38fGLRj9.css" /><link rel="preload" as="style" href="https://www.jobsnepal.com/build/assets/app-fe1K0pdx.css" /><link rel="preload" as="style" href="https://www.jobsnepal.com/build/assets/main-BsSrjcCm.css" /><link rel="stylesheet" href="https://www.jobsnepal.com/build/assets/style-DWRjEJYb.css" data-navigate-track="reload" /><link rel="stylesheet" href="https://www.jobsnepal.com/build/assets/style-9WxHJm-q.css" data-navigate-track="reload" /><link rel="stylesheet" href="https://www.jobsnepal.com/build/assets/tailwind-38fGLRj9.css" data-navigate-track="reload" /><link rel="stylesheet" href="https://www.jobsnepal.com/build/assets/app-fe1K0pdx.css" data-navigate-track="reload" /><link rel="stylesheet" href="https://www.jobsnepal.com/build/assets/main-BsSrjcCm.css" data-navigate-track="reload" /><link rel="apple-touch-icon" href="/assets/front/images/favicons/apple-icon-180x180.png" />
# <link rel="icon" type="image/png" sizes="192x192" href="/assets/front/images/favicons/android-icon-192x192.png" />
# <!-- <link rel="manifest" href="/manifest.json"> -->
# <meta name="msapplication-TileColor" content="#ffffff" />
# <meta name="msapplication-TileImage" content="/assets/images/favicons/ms-icon-144x144.png" />
# <meta name="theme-color" content="#ffffff" />
#     <meta name="description"
#     content="Job & Jobs in Nepal at JobsNepal.com - An online job search and career development for job seekers in Nepal. A common search platform for job seekers, recruiters and employers with resume creating and matching for online job posts." />
# <meta name="keywords" content="jobs in Nepal, online job in Nepal, job vacancies in Nepal, job vacancy in Nepal, job site in Nepal recent, job opportunities in Nepal, job sites in Nepal, find jobs in Nepal, job search in Nepal, job search. " />
# <meta property="og:image" content="https://www.jobsnepal.com/images/logo.png" />
# <meta property="og:title" content="Find Job / Jobs in Nepal - Job, Online Vacancy, Recruitment | JobsNepal" />
# <meta property="og:site_name" content="JobsNepal.com" />
# <meta property="og:type" content="website" />
# <meta property="fb:admins" content="100001300325146" />
#
#
# <!--twitter cards-->
# <meta name="twitter:card" content="summary">
# <meta name="twitter:image" content="https://www.jobsnepal.com/images/logo.png">
# <meta name="twitter:site" content="@JobsNepalDotCom">
# <meta name="twitter:creator" content="@JobsNepalDotCom">
#         <link rel="canonical" href="https://www.jobsnepal.com" />
# <!-- Livewire Styles --><style >[wire\:loading][wire\:loading], [wire\:loading\.delay][wire\:loading\.delay], [wire\:loading\.inline-block][wire\:loading\.inline-block], [wire\:loading\.inline][wire\:loading\.inline], [wire\:loading\.block][wire\:loading\.block], [wire\:loading\.flex][wire\:loading\.flex], [wire\:loading\.table][wire\:loading\.table], [wire\:loading\.grid][wire\:loading\.grid], [wire\:loading\.inline-flex][wire\:loading\.inline-flex] {display: none;}[wire\:loading\.delay\.none][wire\:loading\.delay\.none], [wire\:loading\.delay\.shortest][wire\:loading\.delay\.shortest], [wire\:loading\.delay\.shorter][wire\:loading\.delay\.shorter], [wire\:loading\.delay\.short][wire\:loading\.delay\.short], [wire\:loading\.delay\.default][wire\:loading\.delay\.default], [wire\:loading\.delay\.long][wire\:loading\.delay\.long], [wire\:loading\.delay\.longer][wire\:loading\.delay\.longer], [wire\:loading\.delay\.longest][wire\:loading\.delay\.longest] {display: none;}[wire\:offline][wire\:offline] {display: none;}[wire\:dirty]:not(textarea):not(input):not(select) {display: none;}:root {--livewire-progress-bar-color: #2299dd;}[x-cloak] {display: none !important;}</style>
# </head>
#
# <body>
# <vue-toastify :light-theme="true" :initialDelay="0"></vue-toastify>
# <div wire:snapshot="{&quot;data&quot;:{&quot;activeComponent&quot;:null,&quot;components&quot;:[[],{&quot;s&quot;:&quot;arr&quot;}]},&quot;memo&quot;:{&quot;id&quot;:&quot;aYU0ZZD00iG9SmygePX3&quot;,&quot;name&quot;:&quot;livewire-ui-modal&quot;,&quot;path&quot;:&quot;\/&quot;,&quot;method&quot;:&quot;GET&quot;,&quot;children&quot;:[],&quot;scripts&quot;:[],&quot;assets&quot;:[],&quot;errors&quot;:[],&quot;locale&quot;:&quot;en&quot;},&quot;checksum&quot;:&quot;48c39df3deeccd22cb311a253bb51c01e8dcada9ec76d12e34f736304a5d7d51&quot;}" wire:effects="{&quot;listeners&quot;:[&quot;openModal&quot;,&quot;destroyComponent&quot;]}" wire:id="aYU0ZZD00iG9SmygePX3">
#     <!--[if BLOCK]><![endif]-->        <script type="b8cf734ae744fd30360e2914-text/javascript">(()=>{var t,e={331:()=>{function t(t){return function(t){if(Array.isArray(t))return e(t)}(t)||function(t){if("undefined"!=typeof Symbol&&null!=t[Symbol.iterator]||null!=t["@@iterator"])return Array.from(t)}(t)||function(t,o){if(!t)return;if("string"==typeof t)return e(t,o);var n=Object.prototype.toString.call(t).slice(8,-1);"Object"===n&&t.constructor&&(n=t.constructor.name);if("Map"===n||"Set"===n)return Array.from(t);if("Arguments"===n||/^(?:Ui|I)nt(?:8|16|32)(?:Clamped)?Array$/.test(n))return e(t,o)}(t)||function(){throw new TypeError("Invalid attempt to spread non-iterable instance.\nIn order to be iterable, non-array objects must have a [Symbol.iterator]() method.")}()}function e(t,e){(null==e||e>t.length)&&(e=t.length);for(var o=0,n=new Array(e);o<e;o++)n[o]=t[o];return n}window.LivewireUIModal=function(){return{show:!1,showActiveComponent:!0,activeComponent:!1,componentHistory:[],modalWidth:null,listeners:[],getActiveComponentModalAttribute:function(t){if(void 0!==this.$wire.get("components")[this.activeComponent])return this.$wire.get("components")[this.activeComponent].modalAttributes[t]},closeModalOnEscape:function(t){if(!1!==this.getActiveComponentModalAttribute("closeOnEscape")){var e=!0===this.getActiveComponentModalAttribute("closeOnEscapeIsForceful");this.closeModal(e)}},closeModalOnClickAway:function(t){!1!==this.getActiveComponentModalAttribute("closeOnClickAway")&&this.closeModal(!0)},closeModal:function(){var t=arguments.length>0&&void 0!==arguments[0]&&arguments[0],e=arguments.length>1&&void 0!==arguments[1]?arguments[1]:0,o=arguments.length>2&&void 0!==arguments[2]&&arguments[2];if(!1!==this.show){if(!0===this.getActiveComponentModalAttribute("dispatchCloseEvent")){var n=this.$wire.get("components")[this.activeComponent].name;Livewire.dispatch("modalClosed",{name:n})}if(!0===this.getActiveComponentModalAttribute("destroyOnClose")&&Livewire.dispatch("destroyComponent",{id:this.activeComponent}),e>0)for(var i=0;i<e;i++){if(o){var s=this.componentHistory[this.componentHistory.length-1];Livewire.dispatch("destroyComponent",{id:s})}this.componentHistory.pop()}var r=this.componentHistory.pop();r&&!t&&r?this.setActiveModalComponent(r,!0):this.setShowPropertyTo(!1)}},setActiveModalComponent:function(t){var e=this,o=arguments.length>1&&void 0!==arguments[1]&&arguments[1];if(this.setShowPropertyTo(!0),this.activeComponent!==t){!1!==this.activeComponent&&!1===o&&this.componentHistory.push(this.activeComponent);var n=50;!1===this.activeComponent?(this.activeComponent=t,this.showActiveComponent=!0,this.modalWidth=this.getActiveComponentModalAttribute("maxWidthClass")):(this.showActiveComponent=!1,n=400,setTimeout((function(){e.activeComponent=t,e.showActiveComponent=!0,e.modalWidth=e.getActiveComponentModalAttribute("maxWidthClass")}),300)),this.$nextTick((function(){var o,i=null===(o=e.$refs[t])||void 0===o?void 0:o.querySelector("[autofocus]");i&&setTimeout((function(){i.focus()}),n)}))}},focusables:function(){return t(this.$el.querySelectorAll("a, button, input:not([type='hidden'], textarea, select, details, [tabindex]:not([tabindex='-1'])")).filter((function(t){return!t.hasAttribute("disabled")}))},firstFocusable:function(){return this.focusables()[0]},lastFocusable:function(){return this.focusables().slice(-1)[0]},nextFocusable:function(){return this.focusables()[this.nextFocusableIndex()]||this.firstFocusable()},prevFocusable:function(){return this.focusables()[this.prevFocusableIndex()]||this.lastFocusable()},nextFocusableIndex:function(){return(this.focusables().indexOf(document.activeElement)+1)%(this.focusables().length+1)},prevFocusableIndex:function(){return Math.max(0,this.focusables().indexOf(document.activeElement))-1},setShowPropertyTo:function(t){var e=this;this.show=t,t?document.body.classList.add("overflow-y-hidden"):(document.body.classList.remove("overflow-y-hidden"),setTimeout((function(){e.activeCompone ...
#     <!--[if ENDBLOCK]><![endif]-->
#     <!--[if BLOCK]><![endif]--><!--[if ENDBLOCK]><![endif]-->
#
#     <div
#             x-data="LivewireUIModal()"
#             x-on:close.stop="setShowPropertyTo(false)"
#             x-on:keydown.escape.window="closeModalOnEscape()"
#             x-show="show"
#             class="jn-fixed jn-inset-0 jn-z-[9999] jn-overflow-y-auto"
#             style="display: none;">
#         <div class="jn-flex lg:jn-items-end jn-items-center jn-justify-center jn-min-h-screen jn-px-4 jn-pt-4 jn-pb-10 jn-text-center sm:jn-block sm:jn-p-0">
#             <div
#                     x-show="show"
#                     x-on:click="closeModalOnClickAway()"
#                     x-transition:enter="jn-ease-out jn-duration-300"
#                     x-transition:enter-start="jn-opacity-0"
#                     x-transition:enter-end="jn-opacity-100"
#                     x-transition:leave="jn-ease-in jn-duration-200"
#                     x-transition:leave-start="jn-opacity-100"
#                     x-transition:leave-end="jn-opacity-0"
#                     class="jn-fixed jn-inset-0 jn-transition-all jn-transform">
#                 <div class="jn-absolute jn-inset-0 jn-bg-gray-500 jn-opacity-75"></div>
#             </div>
#
#             <span class="jn-hidden sm:jn-inline-block sm:jn-align-middle sm:jn-h-screen" aria-hidden="true">&#8203;</span>
#
#             <div
#                     x-show="show && showActiveComponent"
#                     x-transition:enter="ease-out duration-300"
#                     x-transition:enter-start="opacity-0 translate-y-4 sm:translate-y-0 sm:scale-95"
#                     x-transition:enter-end="opacity-100 translate-y-0 sm:scale-100"
#                     x-transition:leave="ease-in duration-200"
#                     x-transition:leave-start="opacity-100 translate-y-0 sm:scale-100"
#                     x-transition:leave-end="opacity-0 translate-y-4 sm:translate-y-0 sm:scale-95"
#                     x-bind:class="modalWidth"
#                     class="jn-inline-block jn-w-full jn-align-bottom jn-bg-white jn-rounded-lg jn-text-left jn-overflow-hidden jn-shadow-xl jn-transform jn-transition-all sm:jn-my-8 sm:jn-align-top sm:jn-w-full"
#                     id="modal-container"
#                     x-trap.noscroll.inert="show && showActiveComponent"
#                     aria-modal="true">
#                 <!--[if BLOCK]><![endif]-->                <!--[if ENDBLOCK]><![endif]-->
#             </div>
#         </div>
#     </div>
# </div>
# <header class="container-fluid jn-header fixed-top">
#     <nav class="container navbar navbar-expand-lg jn-bg-primary">
#         <a class="navbar-brand m-0 p-0" href="https://www.jobsnepal.com"><img src="https://www.jobsnepal.com/assets/front/images/jn-logo@2x.png"
#                 alt="JobsNepal.com - Online Jobs Vacancy Recruitment" width="180" height="46" /></a>
#         <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#mainNavigation"
#             aria-controls="mainNavigation" aria-expanded="false" aria-label="Toggle navigation">
#             <span class="navbar-toggler-icon">
#                 <i class="jn-icon-menu"></i>
#             </span>
#         </button>
#         <div class="collapse navbar-collapse pb-2 pb-md-0" id="mainNavigation">
#             <ul class="navbar-nav ml-auto mt-2 mt-lg-0">
#                 <li class="nav-item dropdown">
#                     <a class="nav-link dropdown-toggle" href="#" id="search-navbarDropdownMenuLink" role="button"
#                         data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                         Search
#                     </a>
#                     <div class="dropdown-menu shadow" aria-labelledby="search-navbarDropdownMenuLink">
#                         <a href="https://www.jobsnepal.com/search?q=" class="dropdown-item">Search Job</a>
#                         <div class="dropdown-divider"></div>
#                         <a href="https://www.jobsnepal.com/top-job" class="dropdown-item">Top Jobs</a>
#                         <a href="https://www.jobsnepal.com/hot-job" class="dropdown-item">Hot Jobs</a>
#                         <a href="https://www.jobsnepal.com/normal-job" class="dropdown-item">Normal Jobs</a>
#                         <a href="https://www.jobsnepal.com/instant-jobs" class="dropdown-item">Instant Jobs</a>
#                         <a href="https://www.jobsnepal.com/jobs" class="dropdown-item">Premium Jobs</a>
#                         <div class="dropdown-divider"></div>
#                         <a href="https://www.jobsnepal.com/category/information-technology-jobs" class="dropdown-item">IT
#                             Jobs</a>
#                         <a href="https://www.jobsnepal.com/category/hospitality-tourism-jobs" class="dropdown-item">Hospitality
#                             Jobs</a>
#                         <a href="https://www.jobsnepal.com/category/administration-management-jobs"
#                             class="dropdown-item">Administration/Management
#                             Jobs</a>
#                         <a href="https://www.jobsnepal.com/category/ngo-ingo-jobs" class="dropdown-item">Ngo/Ingo Jobs</a>
#                         <a href="https://www.jobsnepal.com/category/expression-of-interest" class="dropdown-item">Tender Notice, EOI, Bids</a>
#                     </div>
#                 </li>
#                 <li class="nav-item active">
#                     <a class="nav-link" href="https://www.jobsnepal.com/about-us">About Us</a>
#                 </li>
#                 <li class="nav-item dropdown">
#                     <a class="nav-link dropdown-toggle" href="#" id="service-navbarDropdownMenuLink" role="button"
#                         data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                         Services
#                     </a>
#                     <div class="dropdown-menu" aria-labelledby="service-navbarDropdownMenuLink">
#                         <a href="https://www.jobsnepal.com/services/directrecruitment" class="dropdown-item">Direct Recruitment
#                             Service</a>
#                         <a href="https://www.jobsnepal.com/services/vacancy" class="dropdown-item">Vacancy Announcement Service</a>
#                         <a href="https://www.jobsnepal.com/services/webbanner" class="dropdown-item">Web Banner Advertisement
#                             Service</a>
#                     </div>
#                 </li>
#                 <li class="nav-item dropdown">
#                     <a class="nav-link dropdown-toggle" href="#" id="help-navbarDropdownMenuLink" role="button"
#                         data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                         Help
#                     </a>
#                     <div class="dropdown-menu" aria-labelledby="help-navbarDropdownMenuLink">
#                         <a href="https://www.jobsnepal.com/frequently-asked-questions" class="dropdown-item">FAQ</a>
#                     </div>
#                 </li>
#                 <li class="nav-item">
#                     <a class="nav-link" href="https://www.jobsnepal.com/articles" tabindex="-1">Blog</a>
#                 </li>
#                 <li class="nav-item">
#                     <a class="nav-link" href="https://www.jobsnepal.com/contact-us" tabindex="-1">Contact Us</a>
#                 </li>
#             </ul>
#             <!-- <form class="form-inline my-2 my-lg-0 action-links">
#
#
#               </form> -->
#
#             <div class="action-links ml-3 md:ml-0">
#                                 <span class="dropdown">
#                     <button class="btn btn-outline-success action-link-login font-thin font-dosis" onclick="if (!window.__cfRLUnblockHandlers) return false; Livewire.dispatch('openModal', {component: 'front.livewire.login'})" data-cf-modified-b8cf734ae744fd30360e2914-="">
#                         Log In
#                     </button>
#                 </span>
#                 <span class="dropdown">
#                     <button class="btn btn-outline-success action-link-signup dropdown-toggle font-thin font-dosis"
#                         data-toggle="dropdown" aria-expanded="false" type="submit">Sign up</button>
#                     <div class="dropdown-menu dropdown-menu-right register-dropdown">
#                         <a href="https://www.jobsnepal.com/register" class="dropdown-item"><i class="icon-user-tie"></i> Register
#                             JobSeeker
#                             <span class="badge bg-warning ml-2">FREE</span></a>
#                         <a class="dropdown-item" href="https://www.jobsnepal.com/employeer/register">
#                             <i class="icon-office"></i> Register Company
#                             <span class="badge bg-warning ml-2">FREE</span>
#                         </a>
#                     </div>
#                 </span>
#                             </div>
#         </div>
#     </nav>
# </header>
# <div id="app" class="bg-white">
#     <section class="jn-banner">
#     <div class="container">
#         <div class="row search-form">
#             <div class="col-md-12 col-lg-12 col-sm mt-2 mb-4">
#                 <h1 class="jn-text-2xl">Find jobs, vacancy, career online.</h1>
#
#                 <form action="https://www.jobsnepal.com/search">
#                     <div class="d-flex">
#                         <div class="input-group input-job-title">
#                             <div class="input-group-prepend">
#                                 <span class="input-group-text job-icon" id="addon-wrapping"><i class="jn-icon-suitcase"></i></span>
#                             </div>
#                             <input type="text" name="q" class="form-control" placeholder="Job Title, Job Category, Company" aria-label="Username" aria-describedby="addon-wrapping" />
#                         </div>
#
#                         <button type="submit" class="btn btn-sm btn-primary btn-search z-50" aria-label="Search Jobs">
#                             <i class="jn-icon-magnifying-glass"></i>
#                         </button>
#                     </div>
#                 </form>
#             </div>
#         </div>
#     </div>
# </section>
# <main role="main">
#     <!-- section wrapper container -->
#     <section class="content container" style="padding: 10px">
#         <!-- row wrapper  -->
#         <div class="row">
#             <!-- sidebar column  -->
#             <div class="col-lg-3 col-md-4 d-none d-md-block  d-lg-block  d-xl-block">
#                 <!-- hot jobs section and others  -->
#                 <div class="sidebar">
#                                         <h2 class="section-title font-dosis">Hot Jobs</h2>
#                     <div class="hot-content">
#                         <div class="hot-slick-carousel">
#                             <div class="media">
#     <div class="company-logo">
#         <a href="employer/people-in-need/8853" title="People in  Need">
#             <img data-src="https://img.jobsnepal.com/x-small/UCewfnoD3dsYjZ0mzwfG5rdXkGtHpk0w8ugz5jDO.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="People in  Need job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">People in  Need</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/meal-technical-officer-133188" title="MEAL Technical Officer" class="text-sm">
#                 MEAL Technical Officer
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/meal-cfrm-coordinator-133187" title="MEAL-CFRM Coordinator" class="text-sm">
#                 MEAL-CFRM Coordinator
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/sjp-meal-coordinator-for-madhesh-133132" title="SJP MEAL Coordinator for Madhesh" class="text-sm">
#                 SJP MEAL Coordinator for Madhesh
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/international-nepal-fellowship/450" title="International Nepal Fellowship">
#             <img data-src="https://img.jobsnepal.com/x-small/7YRawoHo40pxuyrF6yMltf5IH8F0pb2OulmZqG9U.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="International Nepal Fellowship job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">International Nepal Fellowship</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/quality-improvement-manager-research-officer-re-vacancy-133185" title="Quality Improvement Manager / Research Officer (Re-Vacancy)" class="text-sm">
#                 Quality Improvement Manager / Research Officer (Re-Vacancy)
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/consultant-dermatologist-meal-officer-133092" title="Consultant Dermatologist / MEAL Officer" class="text-sm">
#                 Consultant Dermatologist / MEAL Officer
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/javra-software-nepal-pvt-ltd/2301" title="Javra Software Nepal Pvt. Ltd.">
#             <img data-src="https://img.jobsnepal.com/x-small/xAsuNgIiVOvzrAeYKSLvxTWnFn4P75QnXwgaH5HA.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Javra Software Nepal Pvt. Ltd. job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Javra Software Nepal Pvt. Ltd.</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/senior-python-engineer-133180" title="Senior Python Engineer" class="text-sm">
#                 Senior Python Engineer
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/enpred-nepal/449020" title="ENPRED, Nepal">
#             <img data-src="https://www.jobsnepal.com/img/premium-company.jpg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="ENPRED, Nepal job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">ENPRED, Nepal</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/lkha-athhakatakashha-paravathhakaparashathhana-kanathara-vayavasathapaka-133179" title="लेखा अधिकृत/कृषि प्राविधिक/प्रशोधन केन्द्र व्यवस्थापक" class="text-sm">
#                 लेखा अधिकृत/कृषि प्राविधिक/प्रशोधन केन्द्र व्यवस्थापक
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/deloitte/426935" title="Deloitte">
#             <img data-src="https://img.jobsnepal.com/x-small/3pIEGYZLxqXP57VXWphARcAdd1B1oz1n5NJTeCcv.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Deloitte job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Deloitte</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/short-term-technical-assistance-stta-133177" title="Short Term Technical Assistance (STTA)" class="text-sm">
#                 Short Term Technical Assistance (STTA)
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/request-for-full-application-133171" title="Request for Full Application" class="text-sm">
#                 Request for Full Application
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/request-for-full-application-132802" title="Request for Full Application" class="text-sm">
#                 Request for Full Application
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/nepal-national-dalit-social-welfare-organization-nndswo/10514" title="Nepal National Dalit Social Welfare Organization (NNDSWO)">
#             <img data-src="https://img.jobsnepal.com/x-small/o4hR1j5p244k15hF7WXMAqMzYLZtBZQ5iTXZ2ST5.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Nepal National Dalit Social Welfare Organization (NNDSWO) job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Nepal National Dalit Social Welfare Organization (NNDSWO)</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/chhataravatataka-lga-aavathana-samabnathha-sacana-133176" title="छात्रवृत्तिका लागि आवेदन सम्बन्धि सूचना !" class="text-sm">
#                 छात्रवृत्तिका लागि आवेदन सम्बन्धि सूचना !
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/sindhuli-integrated-development-services-nepal-sids-nepal/9706" title="Sindhuli Integrated Development Services Nepal (SIDS Nepal)">
#             <img data-src="https://img.jobsnepal.com/x-small/NK9TLA44kvWJtKBvu1fekjGQp26OctimQHAQa9yS.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Sindhuli Integrated Development Services Nepal (SIDS Nepal) job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Sindhuli Integrated Development Services Nepal (SIDS Nepal)</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/programme-manager-133175" title="Programme Manager" class="text-sm">
#                 Programme Manager
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/social-awareness-center-sac-nepal/395164" title="Social Awareness Center SAC Nepal">
#             <img data-src="https://img.jobsnepal.com/x-small/42kwmbd7F1kF3UbY1GjlCgSB2U0da5u2ktO99Omt.png" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Social Awareness Center SAC Nepal job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Social Awareness Center SAC Nepal</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/shalvanatha-katashana-aahavana-samavanathha-sacana-133173" title="शिलवन्दी कोटेशन आह्वान सम्वन्धि सूचना" class="text-sm">
#                 शिलवन्दी कोटेशन आह्वान सम्वन्धि सूचना
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/shalbnatha-katashana-aahavana-samavanathha-sacana-133151" title="शिलबन्दी कोटेशन आह्वान सम्वन्धि सूचना" class="text-sm">
#                 शिलबन्दी कोटेशन आह्वान सम्वन्धि सूचना
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/national-federation-of-the-deaf-nepal-ndfn/438593" title="National Federation of the Deaf Nepal (NDFN)">
#             <img data-src="https://img.jobsnepal.com/x-small/rZyfLDmXQBshO823LlI0fro6qMwTVbXO6pd5n4Qe.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="National Federation of the Deaf Nepal (NDFN) job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">National Federation of the Deaf Nepal (NDFN)</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/karamacara-pathaparata-samabnathha-sacana-133168" title="कर्मचारी पदपूर्ति सम्बन्धि सूचना" class="text-sm">
#                 कर्मचारी पदपूर्ति सम्बन्धि सूचना
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/winrock-international-feed-the-future-nepal-usaid-agricultural-inputs/434859" title="Winrock International (Feed the Future Nepal USAID Agricultural Inputs)">
#             <img data-src="https://img.jobsnepal.com/x-small/ruY77sjAr1Wgmfz0d5BUFr7bXHVHdwZXozyvy5LH.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Winrock International (Feed the Future Nepal USAID Agricultural Inputs) job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Winrock International (Feed the Future Nepal USAID Agricultural Inputs)</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/request-for-quotation-rfq-for-duty-free-scooters-re-advertisement-133165" title="Request for Quotation (RFQ) for Duty-Free Scooters (Re-Advertisement)" class="text-sm">
#                 Request for Quotation (RFQ) for Duty-Free Scooters (Re-Advertisement)
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/request-for-proposal-rfp-readvertise-133137" title="Request for Proposal (RFP)-Readvertise" class="text-sm">
#                 Request for Proposal (RFP)-Readvertise
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/request-for-concept-notes-132850" title="Request for Concept Notes" class="text-sm">
#                 Request for Concept Notes
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/oxfam-in-nepal/7963" title="Oxfam in Nepal">
#             <img data-src="https://img.jobsnepal.com/x-small/k2kloZJJHk1hQRYcDDp5WwGxJ3P2kGzkQCk2gs8L.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Oxfam in Nepal job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Oxfam in Nepal</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/consultancy-services-on-oxfam-country-strategy-ocs-review-133162" title="Consultancy Services on Oxfam Country Strategy (OCS Review)" class="text-sm">
#                 Consultancy Services on Oxfam Country Strategy (OCS Review)
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/well-minded-australia/448894" title="Well Minded Australia">
#             <img data-src="https://www.jobsnepal.com/img/premium-company.jpg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Well Minded Australia job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Well Minded Australia</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/executive-assistant-133160" title="Executive Assistant" class="text-sm">
#                 Executive Assistant
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/adra-nepal/2545" title="ADRA Nepal">
#             <img data-src="https://img.jobsnepal.com/x-small/wlpymkjuy5x0utCak5uzK2IjrMGaPc41yzKzG6Xm.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="ADRA Nepal job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">ADRA Nepal</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/call-for-proposal-for-gender-equality-and-social-inclusion-gesi-audit-133152" title="Call for Proposal for Gender Equality and Social Inclusion (GESI) Audit" class="text-sm">
#                 Call for Proposal for Gender Equality and Social Inclusion (GESI) Audit
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/dalit-society-welfare-committee-nepal/401826" title="Dalit Society Welfare Committee Nepal">
#             <img data-src="https://img.jobsnepal.com/x-small/THe4TwxkOB6HMGrDkt2HtvrFKro3RWdnktD60cIO.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Dalit Society Welfare Committee Nepal job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Dalit Society Welfare Committee Nepal</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/karayakarama-sayajaka-project-coordinator-133146" title="कार्यक्रम संयोजक  (Project Coordinator)" class="text-sm">
#                 कार्यक्रम संयोजक  (Project Coordinator)
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/lis-nepal-pvt-ltd-sister-concern-of-yomari-group-of-companies/8922" title="LIS Nepal Pvt. Ltd. (Sister Concern of Yomari Group of Companies)">
#             <img data-src="https://img.jobsnepal.com/x-small/tiCdUbc9F68itAHJC0jVHT3J0yA1DhwYeS2H319E.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="LIS Nepal Pvt. Ltd. (Sister Concern of Yomari Group of Companies) job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">LIS Nepal Pvt. Ltd. (Sister Concern of Yomari Group of Companies)</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/dev-ops-intern-133141" title="Dev Ops Intern" class="text-sm">
#                 Dev Ops Intern
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/sr-system-administrator-132923" title="Sr. System Administrator" class="text-sm">
#                 Sr. System Administrator
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/hr-intern-132921" title="HR Intern" class="text-sm">
#                 HR Intern
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/ratauli-yuba-club-ryc/9675" title="Ratauli Yuba Club (RYC)">
#             <img data-src="https://img.jobsnepal.com/x-small/CKVgyPcLVa705YwV0BRN2V5P6fi4YWsaxmFvfAAx.jpg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Ratauli Yuba Club (RYC) job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Ratauli Yuba Club (RYC)</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/field-officer-133143" title="Field Officer" class="text-sm">
#                 Field Officer
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/karamacara-aavashayakata-133127" title="कर्मचारी आवश्यकता" class="text-sm">
#                 कर्मचारी आवश्यकता
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/usaid-tayar-nepal/8978" title="USAID Tayar Nepal">
#             <img data-src="https://img.jobsnepal.com/x-small/ZFOFUxK8lHkelyjekBNOcOyJjsludjYOqJ2Vhqj7.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="USAID Tayar Nepal job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">USAID Tayar Nepal</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/request-for-proposal-133135" title="REQUEST FOR PROPOSAL" class="text-sm">
#                 REQUEST FOR PROPOSAL
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/request-for-quotation-133108" title="REQUEST FOR QUOTATION" class="text-sm">
#                 REQUEST FOR QUOTATION
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/request-for-proposal-133073" title="REQUEST FOR PROPOSAL" class="text-sm">
#                 REQUEST FOR PROPOSAL
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/national-democratic-institute-for-international-affairs-ndi/1240" title="National Democratic Institute for International Affairs (NDI)">
#             <img data-src="https://img.jobsnepal.com/x-small/yKklvX0KPJ2UlgkEbk6qikMBKcJdtSUJqgKomBYo.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="National Democratic Institute for International Affairs (NDI) job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">National Democratic Institute for International Affairs (NDI)</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/request-for-proposal-rfp-research-institute-133147" title="Request for Proposal (RFP) - Research Institute" class="text-sm">
#                 Request for Proposal (RFP) - Research Institute
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/nepal-bankers-association/9993" title="Nepal Bankers&#039; Association">
#             <img data-src="https://img.jobsnepal.com/x-small/9enRS31b50yArYl2miNvtQHiaqHG98927i763kqx.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Nepal Bankers&#039; Association job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Nepal Bankers&#039; Association</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/itresearch-support-officer-133136" title="IT/Research Support Officer" class="text-sm">
#                 IT/Research Support Officer
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/sosec-nepal/8709" title="SOSEC Nepal">
#             <img data-src="https://img.jobsnepal.com/x-small/acILJlY5IQqSsdu3LADgmpvq7E1vNdtgdTFgvQEm.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="SOSEC Nepal job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">SOSEC Nepal</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/various-positions-133130" title="Various Positions" class="text-sm">
#                 Various Positions
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/heifer-international-nepal/10029" title="Heifer International Nepal">
#             <img data-src="https://img.jobsnepal.com/x-small/nwAC7ZI3VMe684I9ZhwnqCkjbj5IXxVvM9gY2hEX.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Heifer International Nepal job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Heifer International Nepal</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/call-for-expression-of-interest-eoi-for-vendor-roster-133128" title="Call for Expression of Interest (EOI) for Vendor Roster" class="text-sm">
#                 Call for Expression of Interest (EOI) for Vendor Roster
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/danfe-works-enterprises-nepal/448710" title="Danfe Works Enterprises Nepal">
#             <img data-src="https://img.jobsnepal.com/x-small/JbFAA2sV7ofh1ZguziQd5d52Vzl4AFLb1XjAG3HO.png" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Danfe Works Enterprises Nepal job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Danfe Works Enterprises Nepal</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/finance-manager-133126" title="Finance Manager" class="text-sm">
#                 Finance Manager
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/ipas-nepal/378018" title="Ipas Nepal">
#             <img data-src="https://img.jobsnepal.com/x-small/lramZ35CsoXZEKAH04QLxkzpNlYgpkvrJaga90P1.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Ipas Nepal job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Ipas Nepal</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/expression-of-interest-for-vendor-listing-133123" title="Expression of Interest for Vendor Listing" class="text-sm">
#                 Expression of Interest for Vendor Listing
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/habitat-nepal/410765" title="Habitat Nepal">
#             <img data-src="https://img.jobsnepal.com/x-small/YU7OKKkrHt3ONzERoU13gAWGCcKJNwDPsaF4rrXA.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Habitat Nepal job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Habitat Nepal</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/request-for-quotation-4wd-vehicle-133117" title="Request for Quotation – 4WD Vehicle" class="text-sm">
#                 Request for Quotation – 4WD Vehicle
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/tuki-association-sunkoshi/7428" title="Tuki Association Sunkoshi">
#             <img data-src="https://img.jobsnepal.com/x-small/UCSKTTfR3rpbrOBmKl2ZnI7KjlCPGIdSIUXpRWrJ.gif" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Tuki Association Sunkoshi job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Tuki Association Sunkoshi</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/tender-notice-133124" title="TENDER NOTICE" class="text-sm">
#                 TENDER NOTICE
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/cbm-global-nepal-country-office/10406" title="﻿﻿﻿﻿﻿﻿CBM Global Nepal Country Office">
#             <img data-src="https://img.jobsnepal.com/x-small/MLDRat18CWRivB3VJZN6ltJmWGB1zjJGICwwhiAy.jpeg" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="﻿﻿﻿﻿﻿﻿CBM Global Nepal Country Office job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">﻿﻿﻿﻿﻿﻿CBM Global Nepal Country Office</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/call-for-proposal-project-end-evaluation-133122" title="Call for Proposal -Project End Evaluation" class="text-sm">
#                 Call for Proposal -Project End Evaluation
#             </a>
#         </h4>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/expression-of-interest-eoi-karnali-earthquake-recovery-project-partnership-disability-inclusive-livelihood-133007" title="Expression of Interest (EOI)  Karnali Earthquake Recovery Project Partnership: Disability Inclusive Livelihood" class="text-sm">
#                 Expression of Interest (EOI)  Karnali Earthquake Recovery Project Partnership: Disability Inclusive Livelihood
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/sagun-agriculture-cooperative-society-ltd/417922" title="Sagun Agriculture Cooperative Society Ltd.">
#             <img data-src="https://img.jobsnepal.com/x-small/RF8sv20sHSWNLVmUjIir0rlHJanY1O4nncvRd1O3.png" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Sagun Agriculture Cooperative Society Ltd. job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Sagun Agriculture Cooperative Society Ltd.</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/karamacara-tatha-lkha-abhalkha-safatavayara-aavashayakata-samabnathha-sacana-133113" title="कर्मचारी तथा लेखा अभिलेख सफ्टवयर आवश्यकता सम्बन्धि सूचना" class="text-sm">
#                 कर्मचारी तथा लेखा अभिलेख सफ्टवयर आवश्यकता सम्बन्धि सूचना
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/kids-of-kathmandu/448729" title="Kids of kathmandu">
#             <img data-src="https://img.jobsnepal.com/x-small/sJs4lvX09ndHLVtm0HBbNiTntlnUlUMQe7PA1DYD.gif" src="https://www.jobsnepal.com/assets/front/images/gray-back.jpg"
#                 class="lozad mr-3" width="50" height="50" alt="Kids of kathmandu job logo"/>
#         </a>
#     </div>
#     <div class="media-body">
#         <h3 class="mt-0 job-company">Kids of kathmandu</h3>
#                 <h4 class="job-title">
#             <a href="https://www.jobsnepal.com/admin-and-finance-officerproject-manager-133104" title="Admin and Finance Officer/Project Manager" class="text-sm">
#                 Admin and Finance Officer/Project Manager
#             </a>
#         </h4>
#             </div>
# </div>
# <div class="media">
#     <div class="company-logo">
#         <a href="employer/li-bird/5093" title="LI-BIRD">
# ...
#                             </h2>
#                             <h3 class="premium-job-company" title="National Federation of the Deaf Nepal (NDFN)">
#                                 <a href="employer/national-federation-of-the-deaf-nepal-ndfn/438593">
#                                     National Federation of the Deaf Nepal (NDFN)
#                                 </a>
#                             </h3>
#                         </div>
#                     </div>
#                 </td>
#                 <td class='p-1 d-none d-md-table-cell w-0 md:w-1/5'>
#                                         Full Time
#                                     </td>
#                 <td class="p-1 d-none d-md-table-cell w-0 md:w-1/5">12 Days</td>
#             </tr>
#                     </tbody>
#     </table>
# </div>
# <div class="float-right">
#     <a href="https://www.jobsnepal.com/jobs" class="btn btn-info btn-md mt-2 mr-1">View all Jobs</a>
# </div>
#                         </div>
#                     </div>
#                 </div>
#                 <!-- Premium job content section ends -->
#
#             </div>
#             <!-- content column ends -->
#
#         </div>
#     </section>
# </main>
# </div>
# <section class="pt-4 jobs-card-container">
#     <div class="container">
#         <div class="row">
#             <div class="col-md-6 mb-2">
#                 <div class="jobs-card">
#                     <div class="jobs-card-header">
#                         <h2 class="card-title">Jobs by Categories</h2>
#                     </div>
#                     <div class="jobs-card-body">
#                         <div class="row">
#                             <div class="col-md-6">
#                                 <a href="https://www.jobsnepal.com/category/information-technology-jobs" class="jobs-category"  title="Information Technology, IT Jobs">IT
#                                     Jobs</a>
#                                 <a href="https://www.jobsnepal.com/category/hospitality-tourism-jobs"
#                                     class="jobs-category"  title="Hotel and Hospitality Jobs">Hospitality
#                                     Jobs</a>
#                                 <a href="https://www.jobsnepal.com/category/administration-management-jobs"
#                                     class="jobs-category"  title="Managment and Administration Jobs">Administration/Management
#                                     Jobs</a>
#                                 <a href="https://www.jobsnepal.com/category/expression-of-interest" class="jobs-category"  title="Tender Nogice, Expression of Interest EOI, Bids Listings">Tender Notice, EOI, Bids</a>
#                             </div>
#                             <div class="col-md-6">
#                                 <a href="https://www.jobsnepal.com/category/ngo-ingo-jobs" class="jobs-category"  title="Jobs in NGO and INGO Projects">NGO/INGO Jobs</a>
#                                 <a href="https://www.jobsnepal.com/category/accounting-jobs" class="jobs-category"  title="Accounting and Financial Sector Jobs">Accounting</a>
#                                 <a href="https://www.jobsnepal.com/category/engineering-jobs" class="jobs-category" title="Engineering, Architecture, Mechanical, Development Jobs">Engineering</a>
#                                 <a href="https://www.jobsnepal.com/instant-jobs" class="jobs-category"  title="Jobs in Jobs Nepal">Instant Jobs</a>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="jobs-card-footer  pt-2 pb-2">
#                         <a href="https://www.jobsnepal.com/category" class="more-link">See more jobs by categories</a>
#                     </div>
#                 </div>
#             </div>
#             <div class="col-md-3 mb-2">
#                 <div class="jobs-card">
#                     <div class="jobs-card-header">
#                         <h2 class="card-title">Jobs by Cities</h2>
#                     </div>
#                     <div class="jobs-card-body">
#                         <a href="https://www.jobsnepal.com/city/kathmandu" class="jobs-category" title="Jobs in Kathmandu">Kathmandu</a>
#                         <a href="https://www.jobsnepal.com/city/lalitpur" class="jobs-category" title="Jobs in Lalitpur">Lalitpur</a>
#                         <a href="https://www.jobsnepal.com/city/bhaktapur" class="jobs-category" title="Jobs in Bhaktapur">Bhaktapur</a>
#                         <a href="https://www.jobsnepal.com/city/pokhara" class="jobs-category" title="Jobs in Pokhara">Pokhara</a>
#                     </div>
#                     <div class="jobs-card-footer pt-2 pb-2">
#                         <a href="https://www.jobsnepal.com/city" class="more-link">See more jobs by cities</a>
#                     </div>
#                 </div>
#             </div>
#             <div class="col-md-3 mb-2">
#                 <div class="jobs-card">
#     <div class="jobs-card-header">
#         <h2 class="card-title">Jobs by Types</h2>
#     </div>
#     <div class="jobs-card-body">
#         <a href="https://www.jobsnepal.com/job-type/full-time" class="jobs-category"  title="Full time Jobs">FullTime</a>
#         <a href="https://www.jobsnepal.com/job-type/contractor" class="jobs-category"  title="Contract Jobs">Contract</a>
#         <a href="https://www.jobsnepal.com/job-type/other" class="jobs-category"  title="Various other types of Jobs at Jobs Nepal">Other</a>
#         <a href="https://www.jobsnepal.com/job-type/part-time" class="jobs-category"  title="Part time Jobs">Part Time</a>
#     </div>
#     <div class="jobs-card-footer  pt-2 pb-2">
#         <a href="https://www.jobsnepal.com/job-type" class="more-link">See more jobs by types</a>
#     </div>
# </div>
#             </div>
#         </div>
#     </div>
# </section>
# <footer>
#     <div class="container">
#         <div class="row">
#             <div class="col-md-12 col-lg-8 col-sm-12">
#                 <div class="row">
#                     <div class="footer-links-wrapper col-md-4 col-lg-4 col-sm-4">
#                         <h2 class="footer-links-title">For Job Seekers</h2>
#                         <ul class="footer-links">
#                             <li>
#                                 <a href="https://www.jobsnepal.com/register"  title="Create a Free Job Seeker Account">Register <span class="free-registration">Free</span></a>
#                             </li>
#                             <li><a href="https://www.jobsnepal.com/search?q="  title="Find Jobs Online at Jobs Nepal">Find Job </a></li>
#                         </ul>
#                     </div>
#                     <div class="footer-links-wrapper col-md-4 col-lg-4 col-sm-4">
#                         <h2 class="footer-links-title">For Employers</h2>
#                         <ul class="footer-links">
#                             <li>
#                                 <a href="https://www.jobsnepal.com/employeer/register"  title="Create a Free Job Posting Account">Register <span
#                                         class="free-registration">Free</span></a>
#                             </li>
#                             <li><a href="https://www.jobsnepal.com/services/vacancy"  title="Find more about Vacancy and Job Posting Service at Jobs Nepal">Vacancy Announcement</a></li>
#                         </ul>
#                     </div>
#                     <div class="footer-links-wrapper col-md-4 col-lg-4 col-sm-4">
#                         <h2 class="footer-links-title">Links</h2>
#                         <ul class="footer-links">
#                             <li><a href="https://www.jobsnepal.com"  title="Jobs Nepal, find Job, vacancies in Nepal">Home</a></li>
#                             <li><a href="https://www.jobsnepal.com/about-us"  title="About Jobs Nepal and  recruiting and human resources related services provided by Jobs Nepal">About Us</a></li>
#                             <li><a href="https://www.jobsnepal.com/services/webbanner"  title="Advertise your Job postings at Jobs Nepal">Advertise</a></li>
#                             <li><a href="https://www.jobsnepal.com/contact-us"  title="Contact Jobs Nepal for further job related inqueries">Contact Us</a></li>
#                             <li><a href="https://www.jobsnepal.com/frequently-asked-questions"  title="FAQ, Frequently Asked Questing related to Jobs Nepal and Online Job Posting Service">FAQ</a></li>
#                         </ul>
#                     </div>
#                 </div>
#             </div>
#             <div class="col-md-12 col-lg-4 col-sm-12">
#                 <div class="media address-info">
#                     <h2 class="footer-links-title footer-logo">
#                         <img src="https://www.jobsnepal.com/assets/front/images/jn-logo@2x.png" width="170" height="43" alt="Jobs Nepal, Nepal's number 1 job and career portal">
#                     </h2>
#                     <div class="media-body">
#                         <span class="m-1 address">
#                             <i class="jn-icon-map-location"></i>
#                             <span>Kupondole Road, Patan 44600,
#                                 <br> Kathmandu, Nepal</span></span>
#                         <span class="m-1 phone-fax">
#                             <i class="jn-icon-phone"></i>
#                             <span>01-544 7709, 01-544 7710</span>
#                         </span>
#                         <span class="m-1 phone-fax">
#                             <i class="jn-icon-phone"></i>
#                             <span>+977 984 942 6300</span>
#                         </span>
#                         <span class="m-1 email"><i
#                                 class="jn-icon-mail"></i><span>&#105;&#110;&#102;&#111;&#64;&#106;&#111;&#98;&#115;&#110;&#101;&#112;&#97;&#108;&#46;&#99;&#111;&#109;</span></span>
#                     </div>
#                 </div>
#                 <div class="social-links">
#                     <ul class="footer-links">
#                         <li>
#                             <a href="https://www.facebook.com/jobsnepalcom/" title="Jobs Nepal post at Facebook page"><i
#                                     class="jn-icon-facebook"></i></a>
#                         </li>
#                         <li>
#                             <a href="https://twitter.com/jobsnepalc"  title="Jobs Nepal post at Twitter"><i
#                                     class="jn-icon-twitter"></i></a>
#                         </li>
#                         <li>
#                             <a href="https://www.linkedin.com/company/jobnepal-com/about/"  title="Jobs Nepal post at LinkedIn"><i
#                                     class="jn-icon-linkedin"></i></a>
#                         </li>
#                     </ul>
#                 </div>
#             </div>
#         </div>
#     </div>
# </footer>
# <footer>
#     <div class="container-fluid copyright">
#         <div class="container text-center">
#             © 2000 - 2024 JobsNepal Pvt. Ltd. All Right Reserved.
#         </div>
#     </div>
# </footer>
#
# <link rel="preload" as="style" href="https://www.jobsnepal.com/build/assets/app-COzXSpxa.css" /><link rel="modulepreload" href="https://www.jobsnepal.com/build/assets/app-BVT96fg5.js" /><link rel="stylesheet" href="https://www.jobsnepal.com/build/assets/app-COzXSpxa.css" data-navigate-track="reload" /><script type="b8cf734ae744fd30360e2914-module" src="https://www.jobsnepal.com/build/assets/app-BVT96fg5.js" data-navigate-track="reload"></script><script type="b8cf734ae744fd30360e2914-text/javascript">
#     window.onload = function() {
#
#
#             }
# </script>
# <script src="https://code.jquery.com/jquery-3.4.1.min.js" type="b8cf734ae744fd30360e2914-text/javascript"></script>
# <script defer src="https://cdn.jsdelivr.net/npm/popper.js@1.14.7/dist/umd/popper.min.js" integrity="sha384-UO2eT0CpHqdSJQ6hJty5KVphtPhzWj9WO1clHTMGa3JDZwrnQq4sF86dIHNDz0W1" crossorigin="anonymous" type="b8cf734ae744fd30360e2914-text/javascript"></script>
# <script defer src="https://cdn.jsdelivr.net/npm/bootstrap@4.3.1/dist/js/bootstrap.min.js" integrity="sha384-JjSmVgyd0p3pXB1rRibZUAYoIIy6OrQ6VrjIEaFf/nJGzIxFDsf4x0xIM+B07jRM" crossorigin="anonymous" type="b8cf734ae744fd30360e2914-text/javascript"></script>
# <script defer type="b8cf734ae744fd30360e2914-text/javascript" src="https://cdn.jsdelivr.net/npm/lozad/dist/lozad.min.js"></script>
#
# <!-- Google tag (gtag.js) -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-CMXJPW3NCZ" type="b8cf734ae744fd30360e2914-text/javascript"></script>
# <script type="b8cf734ae744fd30360e2914-text/javascript">
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-CMXJPW3NCZ');
# </script>
# <script type="b8cf734ae744fd30360e2914-text/javascript">
#     $(document).ready(function () {
#         lozad().observe();
#     });
#     // Image lazy load
# </script>
# <script type="b8cf734ae744fd30360e2914-text/javascript">
#     $(".sidebar-content a").each(function() {
#         if ('https://www.jobsnepal.com' === this.href) {
#             $(this).addClass('active');
#             $(this).parents().eq(1).css({
#                 'display': 'block'
#             });
#             $(this).parents().eq(2).addClass('nav-item-open');
#         }
#     })
#
#     function activeSidebarMenu(id) {
#         $(id).addClass('active');
#         $(id).parents().eq(1).css({
#             'display': 'block'
#         });
#         $(id).parents().eq(2).addClass('nav-item-open');
#     }
#     var configSummernote = {
#         placeholder: 'Details goes here',
#         toolbar: [
#             ['style', ['style']],
#             ['fontsize', ['fontsize']],
#             ['font', ['bold', 'italic', 'underline', 'font', 'strikethrough', 'superscript', 'subscript']],
#             ['fontname', ['fontname']],
#             ['color', ['color']],
#             ['para', ['ul', 'ol', 'paragraph']],
#             ['height', ['height']],
#             ['insert', ['picture', 'hr', 'link']],
#             ['table', ['table']],
#             ['view', ['fullscreen', 'codeview']]
#         ],
#         fontSizes: ['14', '16', '18', '20', '22', '24', '36'],
#         fontNames: ["Mukta, sans-serif"],
#     }
# </script>
# <script defer src="https://kenwheeler.github.io/slick/slick/slick.min.js" type="b8cf734ae744fd30360e2914-text/javascript"></script>
# <script src="/assets/front/js/front.js" type="b8cf734ae744fd30360e2914-text/javascript"></script>
# <script type="application/ld+json">
#     {
#         "@context": "http://schema.org",
#         "@type": "Organization",
#         "name": "Jobs Nepal",
#         "url": "https://www.jobsnepal.com",
#         "logo": "https://www.jobsnepal.com/images/logo.png",
#         "address": {
#             "@type": "PostalAddress",
#             "streetAddress": "Kupondole Road",
#             "addressLocality": "Patan",
#             "addressRegion": "Lalitpur",
#             "postalCode": "44600",
#             "addressCountry": "Nepal"
#         },
#         "contactPoint": [{
#                 "@type": "ContactPoint",
#                 "contactType": "customer support",
#                 "telephone": "[+977 01-5447709]",
#                 "email": "info@jobsnepal.com"
#             },
#             {
#                 "@type": "ContactPoint",
#                 "contactType": "sales",
#                 "telephone": "[+977 01-5447710]",
#                 "email": "vacancy@jobsnepal.com"
#             }
#         ],
#         "sameAs": [
#             "https://www.facebook.com/jobsnepalcom/",
#             "https://twitter.com/jobsnepalc",
#             "https://www.linkedin.com/company/jobnepal-com/about/"
#         ]
#     }
# </script>
# <script src="/livewire/livewire.min.js?id=239a5c52" data-csrf="xDXC7jknnpFXTxbdY9Rhy1DesSAcx2MMiUjx28Pu" data-update-uri="/livewire/update" data-navigate-once="true" type="b8cf734ae744fd30360e2914-text/javascript"></script>
# <script src="/cdn-cgi/scripts/7d0fa10a/cloudflare-static/rocket-loader.min.js" data-cf-settings="b8cf734ae744fd30360e2914-|49" defer></script></body>
#
# </html>
